# %% [markdown]
# # data analysis
#  - data analysis is used to clean manipulate data
#  - importing pandas lib
# - creating dataset
#   - dictionary of items
#   - list of dictionary
#   - import csv,xslx or jason files
# - get basic insights
# - data selection
#   - row wise selection
#   - column wise selection
# - data cleaning and manipulation

# %%
import pandas as pd

# %%
movies={
    'title':['interception','the matrix','instellar'],
    'year':[2010,1999,2014],
    'rating':[8.8,8.7,8.6],
    'genere':['sci-fi','sci-fi','sci-fi'],
}
df=pd.DataFrame(movies)
df
# Out:
#           title  year  rating  genere
# 0  interception  2010     8.8  sci-fi
# 1    the matrix  1999     8.7  sci-fi
# 2     instellar  2014     8.6  sci-fi

# %%
movies=[
    {'title':'interception','year':2010,'rating':8.8,'genere':'sci-fi'},
    {'title':'the matrix','year':1999,'rating':8.7,'genere':'sci-fi'},
    {'title':'insteller','year':2014,'rating':8.6,'genere':'sci-fi'},
]
df = pd.DataFrame(movies)
df
# Out:
#           title  year  rating  genere
# 0  interception  2010     8.8  sci-fi
# 1    the matrix  1999     8.7  sci-fi
# 2     insteller  2014     8.6  sci-fi

# %%
df=pd.read_csv("kc_house_data.csv")
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head()
#show the first five rows of the DataFrame by default
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.tail()
##show the last five rows of the DataFrame by default
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.tail(15)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21598  8956200760  20141013T000000   541800.0         4       2.50
# 21599  7202300110  20140915T000000   810000.0         4       3.00
# 21600   249000205  20141015T000000  1537000.0         5       3.75
# 21601  5100403806  20150407T000000   467000.0         3       2.50
# 21602   844000965  20140626T000000   224000.0         3       1.75
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# ...

# %%
df.sample()
#gives any random data row
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 18062  7853220610  20140729T000000  457000.0         3        2.5
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 18062         2050      5694     2.0           0     2  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 18062        2050              0      2004             0    98065  47.5331
#
#           long  sqft_living15  sqft_lot15
# 18062 -121.855           2680        7187
#
# [1 rows x 21 columns]

# %%
df.sample(10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1754   5608000700  20140918T000000  1038000.0         3       2.50
# 455    7702010030  20140520T000000   551000.0         3       2.50
# 13783  7796600085  20150108T000000   185000.0         4       1.00
# 14938  7923700020  20141121T000000   450000.0         4       2.00
# 18718  2600140120  20140812T000000   946000.0         4       3.00
# 16864  1566100595  20140514T000000   300000.0         3       1.00
# 17748  1951800040  20140620T000000   488800.0         4       2.25
# 18561  7852150720  20140922T000000   405000.0         3       2.50
# 3522   4083301645  20141024T000000   525000.0         3       1.00
# 9286   1423069095  20140507T000000   600000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1754          4570     10615     2.0           0     0  ...     12
# 455           2830      5802     2.0           0     0  ...      9
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.columns.tolist()
#it gives the name of all the columns
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df.info()
#it gives concise form of summary of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
#describes the statistic summary of the datasdet
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# - row wise selection
#   - iloc- index based selection
#   - loc- label based selection
# - column based selection
#   - single column slection
#     - dictionary like selection
#     - object like selection
#   - multiple column selection
#     - dictionary like selection

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.iloc[3]
#selecyts the third row by index value
# Out:
# id                    2487200875
# date             20141209T000000
# price                   604000.0
# bedrooms                       4
# bathrooms                    3.0
# sqft_living                 1960
# sqft_lot                    5000
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      5
# grade                          7
# sqft_above                  1050
# sqft_basement                910
# yr_built                    1965
# yr_renovated                   0
# zipcode                    98136
# lat                      47.5208
# long                    -122.393
# sqft_living15               1360
# sqft_lot15                  5000
# Name: 3, dtype: object

# %%
df.iloc[-3]
#selects the last third row by index value
# Out:
# id                    1523300141
# date             20140623T000000
# price                   402101.0
# bedrooms                       2
# bathrooms                   0.75
# sqft_living                 1020
# sqft_lot                    1350
# floors                       2.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1020
# sqft_basement                  0
# yr_built                    2009
# yr_renovated                   0
# zipcode                    98144
# lat                      47.5944
# long                    -122.299
# sqft_living15               1020
# sqft_lot15                  2007
# Name: 21610, dtype: object

# %%
df.iloc[-10:-3]
#indexing uis also possible in it
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3        2.5
# 21604  9834201367  20150126T000000   429000.0         3        2.0
# 21605  3448900210  20141014T000000   610685.0         4        2.5
# 21606  7936000429  20150326T000000  1007500.0         4        3.5
# 21607  2997800021  20150219T000000   475000.0         3        2.5
# 21608   263000018  20140521T000000   360000.0         3        2.5
# 21609  6600060120  20150223T000000   400000.0         4        2.5
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21603         2270      5536     2.0           0     0  ...      8
# 21604         1490      1126     3.0           0     0  ...      8
# 21605         2520      6023     2.0           0     0  ...      9
# 21606         3510      7200     2.0           0     0  ...      9
# 21607         1310      1294     2.0           0     0  ...      8
# ...

# %%
df.iloc[[3,5,9,11]]
#gives the specific rows in the Dataset andv we use double wise
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 3   2487200875  20141209T000000   604000.0         4        3.0         1960
# 5   7237550310  20140512T000000  1225000.0         4        4.5         5420
# 9   3793500160  20150312T000000   323000.0         3        2.5         1890
# 11  9212900260  20140527T000000   468000.0         2        1.0         1160
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 3       5000     1.0           0     0  ...      7        1050            910
# 5     101930     1.0           0     0  ...     11        3890           1530
# 9       6560     2.0           0     0  ...      7        1890              0
# 11      6000     1.0           0     0  ...      7         860            300
#
#     yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 3       1965             0    98136  47.5208 -122.393           1360
# ...

# %%
df.iloc[[2,3,4],[-3,-2]]
#specific rows and columns
# Out:
#       long  sqft_living15
# 2 -122.233           2720
# 3 -122.393           1360
# 4 -122.045           1800

# %%
df.iloc[2:5,-10:-5]
#specific colums and rows through slicing
# Out:
#    grade  sqft_above  sqft_basement  yr_built  yr_renovated
# 2      6         770              0      1933             0
# 3      7        1050            910      1965             0
# 4      8        1680              0      1987             0

# %%
df=df.set_index('id')
df
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.loc[5631500400]
#when there is atleast one column that is unique for every value
#we first set the value of unique id as the index value for df and then we use it directley b y writting the unique value in square bracket
# Out:
# date             20150225T000000
# price                   180000.0
# bedrooms                       2
# bathrooms                    1.0
# sqft_living                  770
# sqft_lot                   10000
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          6
# sqft_above                   770
# sqft_basement                  0
# yr_built                    1933
# yr_renovated                   0
# zipcode                    98028
# lat                      47.7379
# long                    -122.233
# sqft_living15               2720
# sqft_lot15                  8062
# Name: 5631500400, dtype: object

# %%
df.loc[[2487200875,1523300141]]
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1523300141  20140623T000000  402101.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 2487200875      5000     1.0           0     0          5      7        1050
# 1523300141      1350     2.0           0     0          3      7        1020
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 2487200875            910      1965             0    98136  47.5208 -122.393
# 1523300141              0      2009             0    98144  47.5944 -122.299
#
#             sqft_living15  sqft_lot15
# id
# 2487200875           1360        5000
# 1523300141           1020        2007

# %%
df[['price','bedrooms']]
#select a single column by name
# Out:
#                price  bedrooms
# id
# 7129300520  221900.0         3
# 6414100192  538000.0         3
# 5631500400  180000.0         2
# 2487200875  604000.0         4
# 1954400510  510000.0         3
# ...              ...       ...
# 263000018   360000.0         3
# 6600060120  400000.0         4
# 1523300141  402101.0         2
# 291310100   400000.0         3
# 1523300157  325000.0         2
#
# [21613 rows x 2 columns]

# %%
df.price
#select a single olumn by name
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %% [markdown]
# # data manipulation
#  - to remove  columns and rows
#  - to rename columns
#  - to delete missing values
#  - to handle missing values
#  - to change the datatype of column
#  - to count the categorical data

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
cols_to_drop =['sqft_living15', 'sqft_lot15']
df=df.drop(columns=cols_to_drop)
df.columns
#drop is used to delete a column or rows from the dataset
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long'],
#       dtype='object')

# %%
df=df.drop(labels=[6414100192])
df
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000   221900.0         3       1.00         1180
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 2487200875  20141209T000000   604000.0         4       3.00         1960
# 1954400510  20150218T000000   510000.0         3       2.00         1680
# 7237550310  20140512T000000  1225000.0         4       4.50         5420
# ...                     ...        ...       ...        ...          ...
# 263000018   20140521T000000   360000.0         3       2.50         1530
# 6600060120  20150223T000000   400000.0         4       2.50         2310
# 1523300141  20140623T000000   402101.0         2       0.75         1020
# 291310100   20150116T000000   400000.0         3       2.50         1600
# 1523300157  20141015T000000   325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
rename={
    'lat':'latitude',
    'long':'longitude',
}
df=df.rename(columns=rename)
df.columns
#rename a column using a dictionary
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
#fillna = replace the value wherever we have null values in the data set 
#dropna = delete the data wherever we have null value , when there is less nujmber of values where they are null
#drop= to delete all the values of a column 
#cateograical value=other than numeric values 
#value_count= to find out how many numbers are present and will check how many times they have 
#id_max=gives the name of the column with the max number that has occured
